# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = np.arange(0,10,0.1)
y = np.sin(1.5)
z = np.cos(x)
df=pd.DataFrame({'time':x,'YVals':y,'ZVals':z})
df
# Out:
#     time     YVals     ZVals
# 0    0.0  0.997495  1.000000
# 1    0.1  0.997495  0.995004
# 2    0.2  0.997495  0.980067
# 3    0.3  0.997495  0.955336
# 4    0.4  0.997495  0.921061
# 5    0.5  0.997495  0.877583
# 6    0.6  0.997495  0.825336
# 7    0.7  0.997495  0.764842
# 8    0.8  0.997495  0.696707
# 9    0.9  0.997495  0.621610
# 10   1.0  0.997495  0.540302
# 11   1.1  0.997495  0.453596
# 12   1.2  0.997495  0.362358
# 13   1.3  0.997495  0.267499
# 14   1.4  0.997495  0.169967
# 15   1.5  0.997495  0.070737
# 16   1.6  0.997495 -0.029200
# 17   1.7  0.997495 -0.128844
# 18   1.8  0.997495 -0.227202
# 19   1.9  0.997495 -0.323290
# 20   2.0  0.997495 -0.416147
# 21   2.1  0.997495 -0.504846
# 22   2.2  0.997495 -0.588501
# 23   2.3  0.997495 -0.666276
# 24   2.4  0.997495 -0.737394
# 25   2.5  0.997495 -0.801144
# 26   2.6  0.997495 -0.856889
# 27   2.7  0.997495 -0.904072
# 28   2.8  0.997495 -0.942222
# 29   2.9  0.997495 -0.970958
# ..   ...       ...       ...
# ...

# %%
df.head()
# Out:
#    time     YVals     ZVals
# 0   0.0  0.997495  1.000000
# 1   0.1  0.997495  0.995004
# 2   0.2  0.997495  0.980067
# 3   0.3  0.997495  0.955336
# 4   0.4  0.997495  0.921061

# %%
df[["time","YVals","ZVals"]][10:16]
# Out:
#     time     YVals     ZVals
# 10   1.0  0.997495  0.540302
# 11   1.1  0.997495  0.453596
# 12   1.2  0.997495  0.362358
# 13   1.3  0.997495  0.267499
# 14   1.4  0.997495  0.169967
# 15   1.5  0.997495  0.070737

# %%
df.to_csv("out.text")

# %%
data=pd.read_csv("out.text")
data
# Out:
#     Unnamed: 0  time     YVals     ZVals
# 0            0   0.0  0.997495  1.000000
# 1            1   0.1  0.997495  0.995004
# 2            2   0.2  0.997495  0.980067
# 3            3   0.3  0.997495  0.955336
# 4            4   0.4  0.997495  0.921061
# 5            5   0.5  0.997495  0.877583
# 6            6   0.6  0.997495  0.825336
# 7            7   0.7  0.997495  0.764842
# 8            8   0.8  0.997495  0.696707
# 9            9   0.9  0.997495  0.621610
# 10          10   1.0  0.997495  0.540302
# 11          11   1.1  0.997495  0.453596
# 12          12   1.2  0.997495  0.362358
# 13          13   1.3  0.997495  0.267499
# 14          14   1.4  0.997495  0.169967
# 15          15   1.5  0.997495  0.070737
# 16          16   1.6  0.997495 -0.029200
# 17          17   1.7  0.997495 -0.128844
# 18          18   1.8  0.997495 -0.227202
# 19          19   1.9  0.997495 -0.323290
# 20          20   2.0  0.997495 -0.416147
# 21          21   2.1  0.997495 -0.504846
# ...

# %%
df.plot()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
