# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# %%
df=pd.read_csv('Obama.csv')

# %%
df.head()
# Out:
#    year state          county  fips  vote_rep  vote_dem  vote_oth  vote_total  \
# 0  2008    AL  Autauga County  1001     17403      6093       145       23641
# 1  2008    AL  Baldwin County  1003     61271     19386       756       81413
# 2  2008    AL  Barbour County  1005      5866      5697        67       11630
# 3  2008    AL     Bibb County  1007      6262      2299        83        8644
# 4  2008    AL   Blount County  1009     20389      3522       356       24267
#
#    pct_rep  pct_dem  pct_oth winner runnerup  pct_winner  \
# 0     73.6     25.8      0.6    rep      dem        73.6
# 1     75.3     23.8      0.9    rep      dem        75.3
# 2     50.4     49.0      0.6    rep      dem        50.4
# 3     72.4     26.6      1.0    rep      dem        72.4
# 4     84.0     14.5      1.5    rep      dem        84.0
#
#    margin_winner_over_runnerup
# 0                         47.8
# 1                         51.5
# 2                          1.4
# ...

# %%
df_swing=df[['pct_dem','pct_rep']]

# %%
df_avg=df[(df['pct_dem']>40) & (df['pct_dem']<50)]
df_avg
# Out:
#       year state                                       county   fips  \
# 2     2008    AL                               Barbour County   1005
# 6     2008    AL                                Butler County   1013
# 8     2008    AL                              Chambers County   1017
# 11    2008    AL                               Choctaw County   1023
# 12    2008    AL                                Clarke County   1025
# 17    2008    AL                               Conecuh County   1035
# 18    2008    AL                                 Coosa County   1037
# 44    2008    AL                               Madison County   1089
# 48    2008    AL                                Mobile County   1097
# 49    2008    AL                                Monroe County   1099
# 53    2008    AL                               Pickens County   1107
# 54    2008    AL                                  Pike County   1109
# 60    2008    AL                             Talladega County   1121
# ...

# %%
df_avg["state"].value_counts()
# Out:
# IN    52
# MN    49
# VA    48
# IA    46
# IL    44
# MI    40
# MO    35
# OH    34
# KY    33
# NC    32
# GA    29
# PA    27
# NY    26
# SD    24
# WV    23
# FL    21
# MS    19
# CA    19
# SC    17
# TX    16
# TN    16
# LA    14
# AL    14
# WI    14
# MD    12
# AK    12
# CO    12
# MT    11
# KS    11
# ND    11
# WA    10
# OR    10
# AR     9
# NE     8
# NJ     6
# OK     6
# ID     6
# NV     6
# AZ     4
# UT     3
# NM     3
# ME     2
# DE     1
# Name: state, dtype: int64

# %%
df_avg=df_avg[['state','county','pct_dem']]
df_IN=df_avg[df_avg.state=='IN']
df_MN=df_avg[df_avg.state=='MN']
df_VA=df_avg[df_avg.state=='VA']

# %%
df_IN1=df_IN['pct_dem']
df_MN1=df_MN['pct_dem']
df_VA1=df_VA['pct_dem']

# %%
df_IN1.mean()
# Out:
# 44.301923076923075

# %%
df_MN1.mean()
# Out:
# 44.9591836734694

# %%
df_VA1.mean()
# Out:
# 45.385625000000005

# %%
df_IN1.median()
# Out:
# 43.9

# %%
df_MN1.median()
# Out:
# 44.83

# %%
df_VA1.median()
# Out:
# 45.215

# %%
ax=df_IN.plot.bar(x='county',y='pct_dem',rot=0)

# %%
ax=df_MN.plot.bar(x='county',y='pct_dem',rot=0)

# %%
ax=df_VA.plot.bar(x='county',y='pct_dem',rot=0)
