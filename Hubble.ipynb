# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
hubble = pd.read_csv("hubble_data.csv")
hubble.head()
# Out:
#    distance  recession_velocity
# 0     0.032                 170
# 1     0.034                 290
# 2     0.214                -130
# 3     0.263                 -70
# 4     0.275                -185

# %%
hubble.rename(index=str, columns={"distance": "dis","recession_velocity":"vel"})
# Out:
#       dis   vel
# 0   0.032   170
# 1   0.034   290
# 2   0.214  -130
# 3   0.263   -70
# 4   0.275  -185
# 5   0.275  -220
# 6   0.450   200
# 7   0.500   290
# 8   0.500   270
# 9   0.630   200
# 10  0.800   300
# 11  0.900   -30
# 12  0.900   650
# 13  0.900   150
# 14  0.900   500
# 15  1.000   920
# 16  1.100   450
# 17  1.100   500
# 18  1.400   500
# 19  1.700   960
# 20  2.000   500
# 21  2.000   850
# 22  2.000   800
# 23  2.000  1090

# %%
hubble.set_index("distance",inplace=True)
hubble.head()
# Out:
#           recession_velocity
# distance
# 0.032                    170
# 0.034                    290
# 0.214                   -130
# 0.263                    -70
# 0.275                   -185

# %%
hubble.plot()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
hubble.sort_values('distance')
# Out:
#           recession_velocity
# distance
# 0.032                    170
# 0.034                    290
# 0.214                   -130
# 0.263                    -70
# 0.275                   -185
# 0.275                   -220
# 0.450                    200
# 0.500                    290
# 0.500                    270
# 0.630                    200
# 0.800                    300
# 0.900                    500
# 0.900                    150
# 0.900                    -30
# 0.900                    650
# 1.000                    920
# 1.100                    450
# 1.100                    500
# 1.400                    500
# 1.700                    960
# 2.000                    800
# 2.000                    500
# 2.000                    850
# 2.000                   1090

# %%
hubble.plot()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
