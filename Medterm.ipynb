# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline

# %%
df=pd.read_csv("epldata_final.csv")
valuable=pd.read_csv("epldata_final.csv")
popularity=pd.read_csv("epldata_final.csv")
MA=pd.read_csv("epldata_final.csv")
A=pd.read_csv("epldata_final.csv")

# %%
df
# Out:
#                         name         club  age position  position_cat  \
# 0             Alexis Sanchez      Arsenal   28       LW             1
# 1                 Mesut Ozil      Arsenal   28       AM             1
# 2                  Petr Cech      Arsenal   35       GK             4
# 3               Theo Walcott      Arsenal   28       RW             1
# 4          Laurent Koscielny      Arsenal   31       CB             3
# 5            Hector Bellerin      Arsenal   22       RB             3
# 6             Olivier Giroud      Arsenal   30       CF             1
# 7              Nacho Monreal      Arsenal   31       LB             3
# 8           Shkodran Mustafi      Arsenal   25       CB             3
# 9                 Alex Iwobi      Arsenal   21       LW             1
# 10              Granit Xhaka      Arsenal   24       DM             2
# 11   Alex Oxlade-Chamberlain      Arsenal   23       RM             2
# ...

# %% [markdown]
# Data for all players

# %%
valuable.sort_values(['market_value'],axis=0, ascending=False, inplace=True)

# %%
valuable.head()
# Out:
#                 name               club  age position  position_cat  \
# 92       Eden Hazard            Chelsea   26       LW             1
# 263       Paul Pogba  Manchester+United   24       CM             2
# 0     Alexis Sanchez            Arsenal   28       LW             1
# 240  Kevin De Bruyne    Manchester+City   26       AM             1
# 241    Sergio Aguero    Manchester+City   29       CF             1
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 92           75.0        4220       10.5   2.30%         224     2.0
# 263          75.0        7435        8.0  19.50%         115     2.0
# 0            65.0        4329       12.0  17.10%         264     3.0
# 240          65.0        2252       10.0  17.50%         199     2.0
# 241          65.0        4046       11.5   9.70%         175     3.0
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 92      Belgium            0        3        5         1            0
# ...

# %% [markdown]
# The most 5 valuable players in the EPL

# %%
popularity.sort_values(['page_views','fpl_value'],axis=0, ascending=False, inplace=True)

# %%
popularity
# Out:
#                       name               club  age position  position_cat  \
# 143           Wayne Rooney            Everton   31       SS             1
# 263             Paul Pogba  Manchester+United   24       CM             2
# 376              Dele Alli          Tottenham   21       CM             2
# 93             Diego Costa            Chelsea   28       CF             1
# 1               Mesut Ozil            Arsenal   28       AM             1
# 0           Alexis Sanchez            Arsenal   28       LW             1
# 251          Gabriel Jesus    Manchester+City   20       CF             1
# 92             Eden Hazard            Chelsea   26       LW             1
# 377             Harry Kane          Tottenham   23       CF             1
# 241          Sergio Aguero    Manchester+City   29       CF             1
# 104         N%27Golo Kante            Chelsea   26       DM             2
# 260          Romelu Lukaku  Manchester+United   24       CF             1
# ...

# %%
popularity=popularity[['name','page_views','fpl_value']]

# %%
popularity.head()
# Out:
#              name  page_views  fpl_value
# 143  Wayne Rooney        7664        7.5
# 263    Paul Pogba        7435        8.0
# 376     Dele Alli        4626        9.5
# 93    Diego Costa        4454       10.0
# 1      Mesut Ozil        4395        9.5

# %% [markdown]
# The most popular player by analysis Page views and fpl value

# %%
valuable=valuable['market_value']
valuable.plot.hist()

# %% [markdown]
# Distribution of Market Value for all data

# %%
valuable=valuable.head()
valuable.plot.hist()

# %% [markdown]
# Distribution of Market Value for most 6 valuable players

# %%
popularity.plot.hist()

# %% [markdown]
# Distribution of page views and fpl value for all data

# %%
popularity=popularity.head()
popularity.plot.hist()

# %% [markdown]
#  Distribution of page views and fpl value for most 6 valuable players

# %% [markdown]
# ---------------------------------------------------------------------

# %% [markdown]
# FPL Valuation:-

# %%
correlation = df['fpl_value'].corr(df['fpl_points'])
# print results 
print('Correlation in metric system: %0.2f' % correlation)
# Out:
# Correlation in metric system: 0.62

# %% [markdown]
# the variables have a perfect positive correlation.Therefore, there is a positive relationship between fpl_value and fpl_points

# %%
MA=MA[['market_value','age']]
MA.plot.hist()

# %%
attackers =A[A.position_cat==1]
attackers ['club'].value_counts().head(2)
# Out:
# Liverpool       11
# Huddersfield    11
# Name: club, dtype: int64

# %% [markdown]
# More number of attackers in the team Huddersfield and Liverpool

# %%
midfielders =A[A.position_cat==2]
midfielders ['club'].value_counts().head(1)
# Out:
# Burnley    8
# Name: club, dtype: int64

# %% [markdown]
# More number of midfielders in the team Burnley

# %%
defenders=A[A.position_cat==3]
defenders['club'].value_counts().head(1)
# Out:
# Arsenal    10
# Name: club, dtype: int64

# %% [markdown]
# More number of defenders in the team Manchester+United

# %%
goalkeepers=A[A.position_cat==4]
goalkeepers['club'].value_counts().head(4)
# Out:
# Arsenal              3
# Manchester+United    3
# Everton              3
# Bournemouth          3
# Name: club, dtype: int64

# %% [markdown]
# More number of goalkeepers in the team Manchester+United

# %%
A.sort_values(['page_views','fpl_value'],axis=0, ascending=False, inplace=True)
A=A[['page_views','fpl_value']]
A=A.head()

# %%
A.plot.hist()
